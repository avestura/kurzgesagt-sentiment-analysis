# %% [markdown]
# # Kurzgesagt Sentiment Analysis
#
# A naive appraoch to analyse how pessimistic/optimistic Kurtgesagt videos are

# %%
import nltk
import json
import os
import pandas as pd

from nltk.sentiment import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\me\AppData\Roaming\nltk_data...
# True

# %%
# All transcript files

transcript_files = [file for file in os.listdir("transcripts") if file.endswith('.json')]

for file in transcript_files:
    print(file)

print(f"total: {len(transcript_files)}")
# Out:
# black-hole-star-the-star-that-shouldn't-exist.json
# change-your-life-one-tiny-step-at-a-time.json
# how-to-terraform-mars-with-lasers.json
# how-we-make-money-on-youtube-with-20m-subs.json
# is-civilization-on-the-brink-of-collapse.json
# lets-travel-to-the-most-extreme-place-in-the-universe.json
# the-black-hole-that-kills-galaxies-quasars.json
# the-deadliest-virus-on-earth.json
# the-horror-of-the-slaver-ant.json
# the-last-human-a-glimpse-into-the-far-future.json
# the-most-complex-language-in-the-world.json
# the-most-dangerous-weapon-in-not-nuclear.json
# the-most-extreme-explosion-in-the-universe.json
# the-reason-why-cancer-is-so-hard-to-beat.json
# what-actually-happens-when-you-are-sick.json
# what-happens-if-a-supervolcano-blows-up.json
# why-aliens-might-already-be-on-their-way-to-us.json
# why-don't-we-shoot-nuclear-waste-into-space.json
# why-you-are-lonely-and-how-to-make-friends.json
# your-body-killed-cancer-5-minutes-ago.json
# total: 20

# %%
def float_to_percentage(num):
    percentage = round(num * 100, 2)
    percentage_str = "{:.0f}%".format(percentage)
    return percentage_str

# %%
sia = SentimentIntensityAnalyzer()

video_data = []

for transcript_file in transcript_files:
    file_path = os.path.join("transcripts", transcript_file)
    with open(file_path, 'r', encoding="utf8") as json_file:
        data = json.load(json_file)

        transcript = " ".join(data)

        sentiment_scores = sia.polarity_scores(transcript)

        video_data.append([
            transcript_file,
            float_to_percentage(sentiment_scores["neu"]),
            float_to_percentage(sentiment_scores["pos"]),
            float_to_percentage(sentiment_scores["neg"]),
            "Negative" if sentiment_scores["compound"] < 0 else "Positive"
        ])

        print(f"Sentiment scores of '{transcript_file}': {sentiment_scores}")
# Out:
# Sentiment scores of 'black-hole-star-the-star-that-shouldn't-exist.json': {'neg': 0.062, 'neu': 0.843, 'pos': 0.095, 'compound': 0.9937}
# Sentiment scores of 'change-your-life-one-tiny-step-at-a-time.json': {'neg': 0.068, 'neu': 0.812, 'pos': 0.12, 'compound': 0.9984}
# Sentiment scores of 'how-to-terraform-mars-with-lasers.json': {'neg': 0.05, 'neu': 0.837, 'pos': 0.113, 'compound': 0.9991}
# Sentiment scores of 'how-we-make-money-on-youtube-with-20m-subs.json': {'neg': 0.035, 'neu': 0.782, 'pos': 0.182, 'compound': 0.9998}
# Sentiment scores of 'is-civilization-on-the-brink-of-collapse.json': {'neg': 0.162, 'neu': 0.743, 'pos': 0.095, 'compound': -0.9994}
# Sentiment scores of 'lets-travel-to-the-most-extreme-place-in-the-universe.json': {'neg': 0.059, 'neu': 0.843, 'pos': 0.098, 'compound': 0.9979}
# Sentiment scores of 'the-black-hole-that-kills-galaxies-quasars.json': {'neg': 0.051, 'neu': 0.829, 'pos': 0.12, 'compound': 0.9992}
# Sentiment scores of 'the-deadliest-virus-on-earth.json': {'neg': 0.132, 'neu': 0.736, 'pos': 0.133, 'compound': -0.9437}
# Sentiment scores of 'the-horror-of-the-slaver-ant.json': {'neg': 0.158, 'neu': 0.723, 'pos': 0.119, 'compound': -0.9987}
# Sentiment scores of 'the-last-human-a-glimpse-into-the-far-future.json': {'neg': 0.068, 'neu': 0.812, 'pos': 0.12, 'compound': 0.9984}
# Sentiment scores of 'the-most-complex-language-in-the-world.json': {'neg': 0.066, 'neu': 0.832, 'pos': 0.102, 'compound': 0.9959}
# Sentiment scores of 'the-most-dangerous-weapon-in-not-nuclear.json': {'neg': 0.126, 'neu': 0.721, 'pos': 0.153, 'compound': 0.9929}
# Sentiment scores of 'the-most-extreme-explosion-in-the-universe.json': {'neg': 0.099, 'neu': 0.8, 'pos': 0.101, 'compound': -0.9109}
# Sentiment scores of 'the-reason-why-cancer-is-so-hard-to-beat.json': {'neg': 0.268, 'neu': 0.608, 'pos': 0.123, 'compound': -0.9999}
# Sentiment scores of 'what-actually-happens-when-you-are-sick.json': {'neg': 0.15, 'neu': 0.691, 'pos': 0.159, 'compound': -0.9197}
# Sentiment scores of 'what-happens-if-a-supervolcano-blows-up.json': {'neg': 0.071, 'neu': 0.793, 'pos': 0.136, 'compound': 0.9992}
# Sentiment scores of 'why-aliens-might-already-be-on-their-way-to-us.json': {'neg': 0.05, 'neu': 0.835, 'pos': 0.115, 'compound': 0.9988}
# Sentiment scores of 'why-don't-we-shoot-nuclear-waste-into-space.json': {'neg': 0.143, 'neu': 0.745, 'pos': 0.113, 'compound': -0.9966}
# Sentiment scores of 'why-you-are-lonely-and-how-to-make-friends.json': {'neg': 0.067, 'neu': 0.668, 'pos': 0.265, 'compound': 1.0}
# Sentiment scores of 'your-body-killed-cancer-5-minutes-ago.json': {'neg': 0.216, 'neu': 0.673, 'pos': 0.112, 'compound': -0.9997}

# %%
pd.DataFrame(video_data, columns=["Transcript", "Neutral", "Positive", "Negative", "Compound"])
# Out:
#                                            Transcript Neutral Positive  \
# 0   black-hole-star-the-star-that-shouldn't-exist....     84%      10%
# 1       change-your-life-one-tiny-step-at-a-time.json     81%      12%
# 2              how-to-terraform-mars-with-lasers.json     84%      11%
# 3     how-we-make-money-on-youtube-with-20m-subs.json     78%      18%
# 4       is-civilization-on-the-brink-of-collapse.json     74%      10%
# 5   lets-travel-to-the-most-extreme-place-in-the-u...     84%      10%
# 6     the-black-hole-that-kills-galaxies-quasars.json     83%      12%
# 7                   the-deadliest-virus-on-earth.json     74%      13%
# 8                   the-horror-of-the-slaver-ant.json     72%      12%
# 9   the-last-human-a-glimpse-into-the-far-future.json     81%      12%
# 10        the-most-complex-language-in-the-world.json     83%      10%
# 11      the-most-dangerous-weapon-in-not-nuclear.json     72%      15%
# 12    the-most-extreme-explosion-in-the-universe.json     80%      10%
# 13      the-reason-why-cancer-is-so-hard-to-beat.json     61%      12%
# 14       what-actually-happens-when-you-are-sick.json     69%      16%
# 15       what-happens-if-a-supervolcano-blows-up.json     79%      14%
# 16  why-aliens-might-already-be-on-their-way-to-us...     84%      12%
# 17   why-don't-we-shoot-nuclear-waste-into-space.json     74%      11%
# 18    why-you-are-lonely-and-how-to-make-friends.json     67%      26%
# 19         your-body-killed-cancer-5-minutes-ago.json     67%      11%
#
#    Negative  Compound
# 0        6%  Positive
# 1        7%  Positive
# 2        5%  Positive
# 3        4%  Positive
# 4       16%  Negative
# 5        6%  Positive
# 6        5%  Positive
# 7       13%  Negative
# 8       16%  Negative
# 9        7%  Positive
# 10       7%  Positive
# 11      13%  Positive
# 12      10%  Negative
# 13      27%  Negative
# 14      15%  Negative
# 15       7%  Positive
# 16       5%  Positive
# 17      14%  Negative
# 18       7%  Positive
# 19      22%  Negative
